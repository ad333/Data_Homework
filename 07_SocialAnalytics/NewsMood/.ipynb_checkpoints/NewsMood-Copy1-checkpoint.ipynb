# %% [markdown]
# # Name:  Ashwini Devkota
# # News Mood

# %% [markdown]
# ## Analysis
#
#     This program utilizes a Python Script to perform a sentiment analysis of the Twitter
#     activity of various news organizations: BBC, CBS, CNN, Fox and New York Times.  Then
#     it presents those findings visually using a scatterplot and a bar graph.
#
#     Here are the three observable trends based on data:
#
#     (1) BBC World had the highest negative polarity scores.  CBS, CNN and New York Times
#         also had negative polarity scores.
#
#     (2) Only Fox News had slightly positive polarity scores.
#
#     (3) The polarity scores of total tweets analyzed for all news organizations were distributed
#         fairly equally among positive, neutral and negative polarity scores.

# %%
# Dependencies
import tweepy
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import time
import seaborn as sns

# %%
# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
# Twitter API Keys
from config import consumer_key, consumer_secret, \
    access_token, access_token_secret

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Target news sources
target_users = ("BBCWorld", "CBSNews", "CNN", "FOXNews", "nytimes")

# Variables for holding sentiments
sentiments = []

# %%
# Loop through all news sources
for user in target_users:
    
    # Counter variable
    counter = 1
    
    # Get all tweets from home feed (total = 100 tweets)
    public_tweets = api.user_timeline(user, count = 100)
    
    # Loop through all tweets
    for tweet in public_tweets:
        
        # Run Vader Analysis on each tweets
        compound = analyzer.polarity_scores(tweet["text"])["compound"]
        pos = analyzer.polarity_scores(tweet["text"])["pos"]
        neu = analyzer.polarity_scores(tweet["text"])["neu"]
        neg = analyzer.polarity_scores(tweet["text"])["neg"]
        tweets_ago = counter
        
        # Add sentiments for each tweets into an array
        sentiments.append({"Compound": compound,
                           "Positive": pos,
                           "Neutral": neu,
                           "Negative": neg,
                           "Tweets Ago": counter,
                           "User": user,
                           "Date": tweet["created_at"],
                           "Tweet Text": tweet["text"]})
    
        # Add to counter
        counter = counter + 1
        
sentiments
# Out:
# [{'Compound': 0.0,
#   'Date': 'Wed Mar 07 08:26:06 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'RT @SallyBundockBBC: #Mattel is marking #InternationalWomensDay with a new set of Barbie dolls - who would you nominate and why? Suggestion…',
#   'Tweets Ago': 1,
#   'User': 'BBCWorld'},
#  {'Compound': -0.4019,
#   'Date': 'Wed Mar 07 08:17:45 +0000 2018',
#   'Negative': 0.252,
#   'Neutral': 0.748,
#   'Positive': 0.0,
#   'Tweet Text': "Terminal illness led to Australia's first same-sex marriage https://t.co/WrPYmBLXE8",
#   'Tweets Ago': 2,
#   'User': 'BBCWorld'},
#  {'Compound': -0.3818,
#   'Date': 'Wed Mar 07 08:17:43 +0000 2018',
#   'Negative': 0.245,
#   'Neutral': 0.755,
#   'Positive': 0.0,
#   'Tweet Text': 'Blackberry sues Facebook in fight over app patents https://t.co/LeM00Hwf84',
#   'Tweets Ago': 3,
#   'User': 'BBCWorld'},
#  {'Compound': 0.1531,
#   'Date': 'Wed Mar 07 08:12:47 +0000 2018',
#   'Negative': 0.268,
#   'Neutral': 0.352,
#   'Positive': 0.38,
#   'Tweet Text': 'Fyre Festival co-founder Billy McFarland admits fraud https://t.co/Hdc266B5do',
#   'Tweets Ago': 4,
#   'User': 'BBCWorld'},
#  {'Compound': -0.2263,
#   'Date': 'Wed Mar 07 07:56:51 +0000 2018',
#   'Negative': 0.087,
#   'Neutral': 0.913,
#   'Positive': 0.0,
#   'Tweet Text': "RT @BBCSteveR: What are today's Russian papers saying about the Sergei Skripal story? There's limited coverage. But one pro-Kremlin paper c…",
#   'Tweets Ago': 5,
#   'User': 'BBCWorld'},
#  {'Compound': -0.3818,
#   'Date': 'Wed Mar 07 07:36:45 +0000 2018',
#   'Negative': 0.342,
#   'Neutral': 0.658,
#   'Positive': 0.0,
#   'Tweet Text': "Bali's battle against plastic pollution https://t.co/fQjzDPbQFh",
#   'Tweets Ago': 6,
#   'User': 'BBCWorld'},
#  {'Compound': 0.5984,
#   'Date': 'Wed Mar 07 07:24:08 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.739,
#   'Positive': 0.261,
#   'Tweet Text': "Tomb Raider star: 'It's all very positive' because of feminist movement https://t.co/S5MkFkHP3v",
#   'Tweets Ago': 7,
#   'User': 'BBCWorld'},
#  {'Compound': -0.5423,
#   'Date': 'Wed Mar 07 04:53:14 +0000 2018',
#   'Negative': 0.364,
#   'Neutral': 0.465,
#   'Positive': 0.171,
#   'Tweet Text': 'US man admits murder of Indian migrant https://t.co/oYu9X8nMKY',
#   'Tweets Ago': 8,
#   'User': 'BBCWorld'},
#  {'Compound': 0.4939,
#   'Date': 'Wed Mar 07 04:42:50 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.686,
#   'Positive': 0.314,
#   'Tweet Text': "Stormy Daniels sues Trump over 'hush agreement' https://t.co/JlGtrLRWsZ",
#   'Tweets Ago': 9,
#   'User': 'BBCWorld'},
#  {'Compound': 0.0,
#   'Date': 'Wed Mar 07 03:55:50 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'RT @SallyBundockBBC: Who would you turn into a #Barbie doll for #InternationalWomensDay? Suggestions to #BBCTheBriefing - Nicola Adams says…',
#   'Tweets Ago': 10,
#   'User': 'BBCWorld'},
#  {'Compound': 0.6369,
#   'Date': 'Wed Mar 07 03:42:27 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.811,
#   'Positive': 0.189,
#   'Tweet Text': "RT @BBCNewsAsia: One of the best captains in international cricket. Inside the mind of India's 'greatest', Sourav Ganguly https://t.co/gsct…",
#   'Tweets Ago': 11,
#   'User': 'BBCWorld'},
#  {'Compound': 0.6166,
#   'Date': 'Wed Mar 07 01:57:30 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.665,
#   'Positive': 0.335,
#   'Tweet Text': "Russia MP: 'I don't feel people up. Well, OK, just a little' https://t.co/DEzy4KPBVx",
#   'Tweets Ago': 12,
#   'User': 'BBCWorld'},
#  {'Compound': -0.2263,
#   'Date': 'Wed Mar 07 01:47:30 +0000 2018',
#   'Negative': 0.087,
#   'Neutral': 0.913,
#   'Positive': 0.0,
#   'Tweet Text': 'RT @BBCNewsAsia: On Thursday it will be four years since Malaysia Airlines flight #MH370 disappeared. With the mystery still unsolved, some…',
#   'Tweets Ago': 13,
#   'User': 'BBCWorld'},
#  {'Compound': 0.0,
#   'Date': 'Wed Mar 07 01:38:31 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'Australia and East Timor sign historic maritime border deal https://t.co/5gICItKskE',
#   'Tweets Ago': 14,
#   'User': 'BBCWorld'},
#  {'Compound': 0.2732,
#   'Date': 'Wed Mar 07 01:13:18 +0000 2018',
#   'Negative': 0.232,
#   'Neutral': 0.421,
#   'Positive': 0.347,
#   'Tweet Text': 'Weinstein Company rescue deal collapses https://t.co/kHxO3sbQaG',
#   'Tweets Ago': 15,
#   'User': 'BBCWorld'},
#  {'Compound': 0.0,
#   'Date': 'Wed Mar 07 01:08:18 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'Lessons delivered by taxi, truck and boat https://t.co/ICckY1EHd1',
#   'Tweets Ago': 16,
#   'User': 'BBCWorld'},
#  {'Compound': 0.0,
#   'Date': 'Wed Mar 07 01:08:18 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': "Sourav Ganguly: Inside the mind of India's 'greatest' cricket captain https://t.co/tAXoKKIWXF",
#   'Tweets Ago': 17,
#   'User': 'BBCWorld'},
#  {'Compound': 0.0,
#   'Date': 'Wed Mar 07 01:08:18 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'MH370: Why families oppose plans for a memorial https://t.co/Wx4vhLBO2g',
#   'Tweets Ago': 18,
#   'User': 'BBCWorld'},
#  {'Compound': 0.0,
#   'Date': 'Wed Mar 07 01:02:44 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'Making boots from hippopotamus and ostrich https://t.co/pWdi7cG4OI',
#   'Tweets Ago': 19,
#   'User': 'BBCWorld'},
#  {'Compound': -0.4767,
#   'Date': 'Wed Mar 07 00:57:38 +0000 2018',
#   'Negative': 0.256,
#   'Neutral': 0.744,
#   'Positive': 0.0,
#   'Tweet Text': "'Haunted by nightmares' of working for US Border Patrol https://t.co/2TEDFt0J5V",
#   'Tweets Ago': 20,
#   'User': 'BBCWorld'},
#  {'Compound': -0.6908,
#   'Date': 'Wed Mar 07 00:47:21 +0000 2018',
#   'Negative': 0.281,
#   'Neutral': 0.719,
#   'Positive': 0.0,
#   'Tweet Text': "North Korea used VX nerve agent to kill leader's brother, says US https://t.co/4mLB0FEnII",
#   'Tweets Ago': 21,
#   'User': 'BBCWorld'},
#  {'Compound': 0.0,
#   'Date': 'Wed Mar 07 00:36:45 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'The girl who sabotaged her own wedding https://t.co/MmfykZHUPl',
#   'Tweets Ago': 22,
#   'User': 'BBCWorld'},
#  {'Compound': -0.4019,
#   'Date': 'Wed Mar 07 00:36:43 +0000 2018',
#   'Negative': 0.31,
#   'Neutral': 0.69,
#   'Positive': 0.0,
#   'Tweet Text': "Washington DC dumps homeless people's belongings https://t.co/QlzK0WVvse",
#   'Tweets Ago': 23,
#   'User': 'BBCWorld'},
#  {'Compound': -0.8591,
#   'Date': 'Tue Mar 06 23:47:23 +0000 2018',
#   'Negative': 0.613,
#   'Neutral': 0.387,
#   'Positive': 0.0,
#   'Tweet Text': 'Canadian man pleads guilty to US terrorism charges https://t.co/1fTaNneVFh',
#   'Tweets Ago': 24,
#   'User': 'BBCWorld'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 22:54:22 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'Albert Einstein note to young female scientist sells at auction https://t.co/R8Pvxmm32m',
#   'Tweets Ago': 25,
#   'User': 'BBCWorld'},
#  {'Compound': -0.3182,
#   'Date': 'Tue Mar 06 22:49:05 +0000 2018',
#   'Negative': 0.223,
#   'Neutral': 0.777,
#   'Positive': 0.0,
#   'Tweet Text': 'Gary Cohn: Key Trump economic policy aide resigns https://t.co/aPY6mgjl8p',
#   'Tweets Ago': 26,
#   'User': 'BBCWorld'},
#  {'Compound': -0.1531,
#   'Date': 'Tue Mar 06 22:38:28 +0000 2018',
#   'Negative': 0.125,
#   'Neutral': 0.781,
#   'Positive': 0.094,
#   'Tweet Text': 'RT @BBCBreaking: US President Donald Trump’s top economic adviser Gary Cohn is to resign - White House https://t.co/bdzGAiguww',
#   'Tweets Ago': 27,
#   'User': 'BBCWorld'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 22:02:59 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': "Trump tariffs: President says EU making business 'impossible' https://t.co/dt5xukZ1b7",
#   'Tweets Ago': 28,
#   'User': 'BBCWorld'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 21:57:03 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'Michelle Obama dances with Parker the portrait girl https://t.co/cBK9lOZphj',
#   'Tweets Ago': 29,
#   'User': 'BBCWorld'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 21:40:48 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': "Rex Tillerson slams China's relationship with Africa https://t.co/a7duVWb0aP",
#   'Tweets Ago': 30,
#   'User': 'BBCWorld'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 21:29:47 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': "A party-goer stole Frances McDormand's Oscar statue and bragged about it on social media https://t.co/fWnWYNH401",
#   'Tweets Ago': 31,
#   'User': 'BBCWorld'},
#  {'Compound': -0.4995,
#   'Date': 'Tue Mar 06 21:22:10 +0000 2018',
#   'Negative': 0.239,
#   'Neutral': 0.645,
#   'Positive': 0.116,
#   'Tweet Text': 'President Donald Trump says "trade wars aren\'t so bad" when the US has a trade deficit with many other countries https://t.co/BI6137GSx4',
#   'Tweets Ago': 32,
#   'User': 'BBCWorld'},
#  {'Compound': -0.1027,
#   'Date': 'Tue Mar 06 21:00:54 +0000 2018',
#   'Negative': 0.149,
#   'Neutral': 0.851,
#   'Positive': 0.0,
#   'Tweet Text': 'Donald Trump cautious on N Korea nuclear disarmament talks https://t.co/YP1t9Cmpnq',
#   'Tweets Ago': 33,
#   'User': 'BBCWorld'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 20:41:23 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': "Argentina abortion: Referendum 'on the table', government says https://t.co/08PuCy3Ghv",
#   'Tweets Ago': 34,
#   'User': 'BBCWorld'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 19:23:37 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'Digging for a son in Eastern Ghouta https://t.co/IX5kA0R2xh',
#   'Tweets Ago': 35,
#   'User': 'BBCWorld'},
#  {'Compound': -0.3182,
#   'Date': 'Tue Mar 06 18:23:28 +0000 2018',
#   'Negative': 0.126,
#   'Neutral': 0.874,
#   'Positive': 0.0,
#   'Tweet Text': 'Lost WW2 aircraft carrier USS Lexington found after 76 years off the coast of Australia\n\nhttps://t.co/T3dq3C3QY8 https://t.co/yzCg9JMki2',
#   'Tweets Ago': 36,
#   'User': 'BBCWorld'},
#  {'Compound': -0.4939,
#   'Date': 'Tue Mar 06 17:48:34 +0000 2018',
#   'Negative': 0.348,
#   'Neutral': 0.652,
#   'Positive': 0.0,
#   'Tweet Text': "Watch Frances McDormand's Oscar being stolen https://t.co/Lq8DnGZwLI",
#   'Tweets Ago': 37,
#   'User': 'BBCWorld'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 17:28:55 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'Crowd catches little girl from ski lift fall https://t.co/CvM33wpmzK',
#   'Tweets Ago': 38,
#   'User': 'BBCWorld'},
#  {'Compound': -0.2263,
#   'Date': 'Tue Mar 06 16:46:28 +0000 2018',
#   'Negative': 0.098,
#   'Neutral': 0.844,
#   'Positive': 0.058,
#   'Tweet Text': 'RT @BBCSport: Fiorentina have retired the shirt number worn by Davide Astori.\n\nHis former club Cagliari have done the same.\n\n👉 https://t.co…',
#   'Tweets Ago': 39,
#   'User': 'BBCWorld'},
#  {'Compound': -0.4767,
#   'Date': 'Tue Mar 06 16:36:56 +0000 2018',
#   'Negative': 0.279,
#   'Neutral': 0.721,
#   'Positive': 0.0,
#   'Tweet Text': 'Rwanda church closures: Pastors arrested for defying order https://t.co/a7O9AdBvhD',
#   'Tweets Ago': 40,
#   'User': 'BBCWorld'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 16:32:17 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'Leaders from North Korea, China, Uganda, Russia, Iraq, Cuba and Syria https://t.co/hO105CFul9',
#   'Tweets Ago': 41,
#   'User': 'BBCWorld'},
#  {'Compound': -0.7783,
#   'Date': 'Tue Mar 06 16:17:44 +0000 2018',
#   'Negative': 0.459,
#   'Neutral': 0.541,
#   'Positive': 0.0,
#   'Tweet Text': 'USS Lexington: World War Two aircraft carrier wreck found https://t.co/m8oUxkAjTc',
#   'Tweets Ago': 42,
#   'User': 'BBCWorld'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 16:12:46 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'The future of fast food? 🍔 https://t.co/EJVxGJCKd7',
#   'Tweets Ago': 43,
#   'User': 'BBCWorld'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 15:58:16 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': "'Their blood is on your hands' https://t.co/l01nszDJVK",
#   'Tweets Ago': 44,
#   'User': 'BBCWorld'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 15:53:22 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'Trump slumps on Forbes billionaires list https://t.co/O0ksA4gBQs',
#   'Tweets Ago': 45,
#   'User': 'BBCWorld'},
#  {'Compound': 0.6705,
#   'Date': 'Tue Mar 06 15:36:10 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.776,
#   'Positive': 0.224,
#   'Tweet Text': 'RT @BBCFergusWalsh: Four dementia scientists share 1m Euro brain prize for pivotal work unpicking the protein changes that lead to Alzheime…',
#   'Tweets Ago': 46,
#   'User': 'BBCWorld'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 15:25:24 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'RT @BBCNews: When a robin photobombs your picture… \n\n@AmandaPache, from Edinburgh, was filming a walk in the snow when this happened https:…',
#   'Tweets Ago': 47,
#   'User': 'BBCWorld'},
#  {'Compound': 0.3818,
#   'Date': 'Tue Mar 06 14:58:12 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.816,
#   'Positive': 0.184,
#   'Tweet Text': 'RT @BBC_HaveYourSay: RuPaul called the trans community “heroes of our shared LGBTQ movement” in his apology 🏳️\u200d🌈\n\nhttps://t.co/do7V7kTGUQ',
#   'Tweets Ago': 48,
#   'User': 'BBCWorld'},
#  {'Compound': 0.8225,
#   'Date': 'Tue Mar 06 14:34:51 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.479,
#   'Positive': 0.521,
#   'Tweet Text': "'Super Monster Wolf' a success in Japan farming trials https://t.co/V0mYNFz0mw",
#   'Tweets Ago': 49,
#   'User': 'BBCWorld'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 14:21:11 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'What is populism, and what does the term actually mean? https://t.co/GIMtXSrh0D',
#   'Tweets Ago': 50,
#   'User': 'BBCWorld'},
#  {'Compound': -0.7351,
#   'Date': 'Tue Mar 06 13:54:46 +0000 2018',
#   'Negative': 0.508,
#   'Neutral': 0.492,
#   'Positive': 0.0,
#   'Tweet Text': "Russian plane crash in Syria 'kills 32' https://t.co/VAak593ePD",
#   'Tweets Ago': 51,
#   'User': 'BBCWorld'},
#  {'Compound': -0.6124,
#   'Date': 'Tue Mar 06 13:47:52 +0000 2018',
#   'Negative': 0.193,
#   'Neutral': 0.746,
#   'Positive': 0.061,
#   'Tweet Text': 'RT @BBCBreaking: Russian military plane crashes in Syria killing 26 passengers and six crew members, defence ministry says https://t.co/sJx…',
#   'Tweets Ago': 52,
#   'User': 'BBCWorld'},
#  {'Compound': -0.4215,
#   'Date': 'Tue Mar 06 13:34:58 +0000 2018',
#   'Negative': 0.219,
#   'Neutral': 0.781,
#   'Positive': 0.0,
#   'Tweet Text': 'Diver swims through thick soup of plastic waste near Bali https://t.co/u3NbHqmYln',
#   'Tweets Ago': 53,
#   'User': 'BBCWorld'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 13:09:54 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'Estonian district votes to get cannabis leaf flag https://t.co/xsW4OojXPG',
#   'Tweets Ago': 54,
#   'User': 'BBCWorld'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 12:33:18 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'Diver films sea of plastic off Nusa Penida near Bali https://t.co/KIcXSDHzcn',
#   'Tweets Ago': 55,
#   'User': 'BBCWorld'},
#  {'Compound': 0.4939,
#   'Date': 'Tue Mar 06 12:21:35 +0000 2018',
#   'Negative': 0.097,
#   'Neutral': 0.664,
#   'Positive': 0.239,
#   'Tweet Text': 'RT @BBCSport: A great gesture.\n\nFiorentina and Cagliari have retired the shirt number worn by Davide Astori.\n\nMore: https://t.co/zwgwAocKba…',
#   'Tweets Ago': 56,
#   'User': 'BBCWorld'},
#  {'Compound': 0.34,
#   'Date': 'Tue Mar 06 12:10:57 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.726,
#   'Positive': 0.274,
#   'Tweet Text': 'France to fix legal age of sexual consent as 15 https://t.co/wy8ZNsoaSO',
#   'Tweets Ago': 57,
#   'User': 'BBCWorld'},
#  {'Compound': -0.34,
#   'Date': 'Tue Mar 06 12:01:15 +0000 2018',
#   'Negative': 0.231,
#   'Neutral': 0.769,
#   'Positive': 0.0,
#   'Tweet Text': 'Florida shooting: State lawmakers pass gun control measures https://t.co/47vnK7PlhY',
#   'Tweets Ago': 58,
#   'User': 'BBCWorld'},
#  {'Compound': 0.4215,
#   'Date': 'Tue Mar 06 12:01:15 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.763,
#   'Positive': 0.237,
#   'Tweet Text': "World's last male northern white rhino Sudan improves slightly https://t.co/jP2x0pIyz4",
#   'Tweets Ago': 59,
#   'User': 'BBCWorld'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 11:43:07 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': "Oldest message in a bottle found on beach in Western Australia\n\nIt's almost 132 years old 😲\n\nhttps://t.co/1nTKs6kAd7 https://t.co/Z6TJHAQKcN",
#   'Tweets Ago': 60,
#   'User': 'BBCWorld'},
#  {'Compound': -0.4939,
#   'Date': 'Tue Mar 06 11:38:43 +0000 2018',
#   'Negative': 0.314,
#   'Neutral': 0.686,
#   'Positive': 0.0,
#   'Tweet Text': "Hong Kong 'tiger' scare after feline sighting https://t.co/prRP0Q5aa1",
#   'Tweets Ago': 61,
#   'User': 'BBCWorld'},
#  {'Compound': -0.7906,
#   'Date': 'Tue Mar 06 11:21:00 +0000 2018',
#   'Negative': 0.5,
#   'Neutral': 0.5,
#   'Positive': 0.0,
#   'Tweet Text': "Syria war: 'Chlorine attack' on besieged Eastern Ghouta https://t.co/51skSNZBah",
#   'Tweets Ago': 62,
#   'User': 'BBCWorld'},
#  {'Compound': -0.8625,
#   'Date': 'Tue Mar 06 11:16:35 +0000 2018',
#   'Negative': 0.578,
#   'Neutral': 0.422,
#   'Positive': 0.0,
#   'Tweet Text': 'Sri Lanka violence: State of emergency declared over attacks https://t.co/nkBX7UTmTR',
#   'Tweets Ago': 63,
#   'User': 'BBCWorld'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 10:49:57 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'New Zealand census campaigner takes to his TARDIS https://t.co/MGzKZgsM0z',
#   'Tweets Ago': 64,
#   'User': 'BBCWorld'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 10:46:08 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': "Life of Pi actor has 'rare disease' https://t.co/k5YUe7iIDj",
#   'Tweets Ago': 65,
#   'User': 'BBCWorld'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 10:37:07 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'Oldest message in a bottle found on West Australia beach https://t.co/PedW4Ur0Jp',
#   'Tweets Ago': 66,
#   'User': 'BBCWorld'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 09:54:45 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'RT @BBCSport: 🎾 WTA beware... Serena is back! https://t.co/njCUjsVIXO',
#   'Tweets Ago': 67,
#   'User': 'BBCWorld'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 08:49:06 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': "The story of women's football in 10 objects https://t.co/lgTnzIASOH",
#   'Tweets Ago': 68,
#   'User': 'BBCWorld'},
#  {'Compound': -0.4588,
#   'Date': 'Tue Mar 06 08:45:37 +0000 2018',
#   'Negative': 0.12,
#   'Neutral': 0.88,
#   'Positive': 0.0,
#   'Tweet Text': "RT @BBCSport: 'Oh captain, my captain. Why did you not come down to have breakfast with us all?'\n\nA heartbreaking tribute to Davide Astori…",
#   'Tweets Ago': 69,
#   'User': 'BBCWorld'},
#  {'Compound': 0.4466,
#   'Date': 'Tue Mar 06 08:36:16 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.891,
#   'Positive': 0.109,
#   'Tweet Text': 'RT @BBCSport: "As long as I\'m moving forward, even if it\'s at a turtle\'s pace, then I\'m OK with that."\n\nSerena Williams is back 👊\n\nMore fro…',
#   'Tweets Ago': 70,
#   'User': 'BBCWorld'},
#  {'Compound': -0.4215,
#   'Date': 'Tue Mar 06 08:35:40 +0000 2018',
#   'Negative': 0.123,
#   'Neutral': 0.877,
#   'Positive': 0.0,
#   'Tweet Text': 'RT @BBCMonitoring: Kremlin spokesman Dmitry Peskov calls the incident "tragic" but says Moscow has no information on what happened to #Skri…',
#   'Tweets Ago': 71,
#   'User': 'BBCWorld'},
#  {'Compound': -0.6249,
#   'Date': 'Tue Mar 06 08:35:33 +0000 2018',
#   'Negative': 0.181,
#   'Neutral': 0.819,
#   'Positive': 0.0,
#   'Tweet Text': 'RT @SallyBundockBBC: Should the food industry be forced to cut the fat? Should we be told by a government body how many calories we can eat…',
#   'Tweets Ago': 72,
#   'User': 'BBCWorld'},
#  {'Compound': 0.2732,
#   'Date': 'Tue Mar 06 08:31:17 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.811,
#   'Positive': 0.189,
#   'Tweet Text': 'RT @BBCNews: A surprising new afterlife for chewing gum ♻️\n\nhttps://t.co/1d1oT6aQoW',
#   'Tweets Ago': 73,
#   'User': 'BBCWorld'},
#  {'Compound': -0.4404,
#   'Date': 'Tue Mar 06 08:02:11 +0000 2018',
#   'Negative': 0.244,
#   'Neutral': 0.756,
#   'Positive': 0.0,
#   'Tweet Text': 'Kobe Steel chief Hiroya Kawasaki quits after data scandal https://t.co/lewlw9HD15',
#   'Tweets Ago': 74,
#   'User': 'BBCWorld'},
#  {'Compound': -0.4019,
#   'Date': 'Tue Mar 06 08:01:09 +0000 2018',
#   'Negative': 0.119,
#   'Neutral': 0.881,
#   'Positive': 0.0,
#   'Tweet Text': "RT @BBCSteveR: As a former Russian double agent fights for his life in a UK hospital, today's Russian papers quote Vladimir Putin thanking…",
#   'Tweets Ago': 75,
#   'User': 'BBCWorld'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 07:22:29 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'Yusuf, 14, aims to be first US Muslim president https://t.co/GM0mC0gnAi',
#   'Tweets Ago': 76,
#   'User': 'BBCWorld'},
#  {'Compound': -0.6249,
#   'Date': 'Tue Mar 06 07:18:09 +0000 2018',
#   'Negative': 0.339,
#   'Neutral': 0.661,
#   'Positive': 0.0,
#   'Tweet Text': 'Rohingya crisis: UN envoy says ethnic cleansing continues https://t.co/j6TmE4o2hb',
#   'Tweets Ago': 77,
#   'User': 'BBCWorld'},
#  {'Compound': 0.25,
#   'Date': 'Tue Mar 06 07:18:09 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.8,
#   'Positive': 0.2,
#   'Tweet Text': 'Emma Watson jokes she needs a tattoo proof reader https://t.co/UYBob11AjG',
#   'Tweets Ago': 78,
#   'User': 'BBCWorld'},
#  {'Compound': -0.7351,
#   'Date': 'Tue Mar 06 06:29:03 +0000 2018',
#   'Negative': 0.547,
#   'Neutral': 0.312,
#   'Positive': 0.141,
#   'Tweet Text': 'Top S Korean politician resigns over rape https://t.co/nrdTYIQTec',
#   'Tweets Ago': 79,
#   'User': 'BBCWorld'},
#  {'Compound': -0.4019,
#   'Date': 'Tue Mar 06 06:21:27 +0000 2018',
#   'Negative': 0.194,
#   'Neutral': 0.737,
#   'Positive': 0.069,
#   'Tweet Text': 'RT @BBCNewsAsia: A South Korean politician once tipped as a presidential contender has resigned after his secretary publicly accused him of…',
#   'Tweets Ago': 80,
#   'User': 'BBCWorld'},
#  {'Compound': -0.3818,
#   'Date': 'Tue Mar 06 05:43:48 +0000 2018',
#   'Negative': 0.245,
#   'Neutral': 0.755,
#   'Positive': 0.0,
#   'Tweet Text': 'Panama hotel removes Trump branding after court battle https://t.co/WnQUXn2AiQ',
#   'Tweets Ago': 81,
#   'User': 'BBCWorld'},
#  {'Compound': -0.3818,
#   'Date': 'Tue Mar 06 04:54:34 +0000 2018',
#   'Negative': 0.224,
#   'Neutral': 0.776,
#   'Positive': 0.0,
#   'Tweet Text': "Afrin: What is going on in Syria's other battle? https://t.co/WfZ9BlFlGb",
#   'Tweets Ago': 82,
#   'User': 'BBCWorld'},
#  {'Compound': -0.1531,
#   'Date': 'Tue Mar 06 04:46:31 +0000 2018',
#   'Negative': 0.211,
#   'Neutral': 0.789,
#   'Positive': 0.0,
#   'Tweet Text': 'Child marriage numbers falling, says Unicef https://t.co/5Q28Q7V5e7',
#   'Tweets Ago': 83,
#   'User': 'BBCWorld'},
#  {'Compound': -0.3182,
#   'Date': 'Tue Mar 06 04:28:34 +0000 2018',
#   'Negative': 0.187,
#   'Neutral': 0.813,
#   'Positive': 0.0,
#   'Tweet Text': 'USS Lexington: Lost WW2 aircraft carrier found after 76 years https://t.co/X88a5mWv8y',
#   'Tweets Ago': 84,
#   'User': 'BBCWorld'},
#  {'Compound': 0.5859,
#   'Date': 'Tue Mar 06 02:30:06 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.853,
#   'Positive': 0.147,
#   'Tweet Text': 'RT @BBCNewsAsia: Who says that beauty only comes in one size? \n\nPlus-size actress and Taiwanese social media celeb Wang Chi wants to prove…',
#   'Tweets Ago': 85,
#   'User': 'BBCWorld'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 01:44:14 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'RT @BBCNewsAsia: Are you one of the WeChat billion? https://t.co/QY7ZsOnWhH',
#   'Tweets Ago': 86,
#   'User': 'BBCWorld'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 01:40:31 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'RT @BBCNewsAsia: North Korea\'s Kim Jong-un says he wants to "write a new history of national reunification" with South Korea, state media r…',
#   'Tweets Ago': 87,
#   'User': 'BBCWorld'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 00:59:31 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'WeChat hits one billion monthly users - are you one of them? https://t.co/Qlygr0ZZNN',
#   'Tweets Ago': 88,
#   'User': 'BBCWorld'},
#  {'Compound': -0.6369,
#   'Date': 'Tue Mar 06 00:55:11 +0000 2018',
#   'Negative': 0.296,
#   'Neutral': 0.704,
#   'Positive': 0.0,
#   'Tweet Text': "Is India's Bangalore doomed to be the next Cape Town? https://t.co/wxgjNFHrBS",
#   'Tweets Ago': 89,
#   'User': 'BBCWorld'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 00:55:11 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'Fancy charging up your electric car in 10 minutes? https://t.co/XmZeMDu7FL',
#   'Tweets Ago': 90,
#   'User': 'BBCWorld'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 00:50:58 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'A different portrait of black fatherhood https://t.co/iSr4EFLDvn',
#   'Tweets Ago': 91,
#   'User': 'BBCWorld'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 00:37:47 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': "Should China's Xi Jinping be president for life? https://t.co/xM5LrJdnig",
#   'Tweets Ago': 92,
#   'User': 'BBCWorld'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 00:33:37 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': "N Korea's Kim 'to advance' closer ties with South https://t.co/g8D2rv9Nh0",
#   'Tweets Ago': 93,
#   'User': 'BBCWorld'},
#  {'Compound': -0.6249,
#   'Date': 'Mon Mar 05 23:21:52 +0000 2018',
#   'Negative': 0.369,
#   'Neutral': 0.631,
#   'Positive': 0.0,
#   'Tweet Text': 'Syria crisis: Aid convoy inside Eastern Ghouta https://t.co/h9KQ9lxDCa',
#   'Tweets Ago': 94,
#   'User': 'BBCWorld'},
#  {'Compound': 0.0,
#   'Date': 'Mon Mar 05 23:21:52 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': "'Maisie is the face of change' https://t.co/fS5gdgQGxQ",
#   'Tweets Ago': 95,
#   'User': 'BBCWorld'},
#  {'Compound': 0.4588,
#   'Date': 'Mon Mar 05 22:33:54 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.75,
#   'Positive': 0.25,
#   'Tweet Text': 'Oscars 2018: US TV audience smallest for awards ceremony https://t.co/UegYh8KClM',
#   'Tweets Ago': 96,
#   'User': 'BBCWorld'},
#  {'Compound': 0.5574,
#   'Date': 'Mon Mar 05 22:25:22 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.66,
#   'Positive': 0.34,
#   'Tweet Text': 'NFL wowed by one-handed player Shaquem Griffin https://t.co/bkgiY8bo6K',
#   'Tweets Ago': 97,
#   'User': 'BBCWorld'},
#  {'Compound': 0.0,
#   'Date': 'Mon Mar 05 21:02:08 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'Russian spy incident: What we know https://t.co/usdtsWH7Hu',
#   'Tweets Ago': 98,
#   'User': 'BBCWorld'},
#  {'Compound': 0.0,
#   'Date': 'Mon Mar 05 21:02:08 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'Trump-Russia: Ex-aide refuses to co-operate with Mueller probe https://t.co/h9McKQN4tg',
#   'Tweets Ago': 99,
#   'User': 'BBCWorld'},
#  {'Compound': 0.0,
#   'Date': 'Mon Mar 05 20:49:21 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': "Tree 'planted by George Washington' toppled in winter storm https://t.co/O6NhrWHzWM",
#   'Tweets Ago': 100,
#   'User': 'BBCWorld'},
#  {'Compound': -0.34,
#   'Date': 'Wed Mar 07 08:33:08 +0000 2018',
#   'Negative': 0.146,
#   'Neutral': 0.854,
#   'Positive': 0.0,
#   'Tweet Text': 'DNA leads to arrest in 1986 cold case slayings of two young women https://t.co/MvlCE4ftoX https://t.co/XQ0nkGJeCQ',
#   'Tweets Ago': 1,
#   'User': 'CBSNews'},
#  {'Compound': -0.4215,
#   'Date': 'Wed Mar 07 08:18:10 +0000 2018',
#   'Negative': 0.157,
#   'Neutral': 0.843,
#   'Positive': 0.0,
#   'Tweet Text': 'Man who yelled "get out my country" before shooting immigrants in bar pleads guilty https://t.co/66UvvMkSUu https://t.co/oNlJeuzM8j',
#   'Tweets Ago': 2,
#   'User': 'CBSNews'},
#  {'Compound': -0.7579,
#   'Date': 'Wed Mar 07 08:03:28 +0000 2018',
#   'Negative': 0.394,
#   'Neutral': 0.606,
#   'Positive': 0.0,
#   'Tweet Text': 'Video shows man holding girl, 4, amid violent bar fight https://t.co/b00RQAO0vW https://t.co/E9YwTJ1856',
#   'Tweets Ago': 3,
#   'User': 'CBSNews'},
#  {'Compound': 0.0,
#   'Date': 'Wed Mar 07 07:48:04 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'GoPro footage captures avalanche trapping snowboarder on California mountain https://t.co/FNaFQlTSZE https://t.co/VPDxhG2A8q',
#   'Tweets Ago': 4,
#   'User': 'CBSNews'},
#  {'Compound': -0.802,
#   'Date': 'Wed Mar 07 07:33:06 +0000 2018',
#   'Negative': 0.419,
#   'Neutral': 0.581,
#   'Positive': 0.0,
#   'Tweet Text': 'Tony Award-winning actress injured, daughter killed by car in crosswalk https://t.co/rPO7RgZ8Xc https://t.co/Lm5NseIaQK',
#   'Tweets Ago': 5,
#   'User': 'CBSNews'},
#  {'Compound': 0.0,
#   'Date': 'Wed Mar 07 07:18:10 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'Prosecutor: Mom returned to work after 8-year-old son shot sister, 4 https://t.co/QHqxZP3eMD https://t.co/QGdJQ5Aodv',
#   'Tweets Ago': 6,
#   'User': 'CBSNews'},
#  {'Compound': -0.2263,
#   'Date': 'Wed Mar 07 07:03:10 +0000 2018',
#   'Negative': 0.119,
#   'Neutral': 0.881,
#   'Positive': 0.0,
#   'Tweet Text': 'Ex-ESPN on-air personality says in lawsuit male employees openly watched porn at work https://t.co/pjEQe3l38B https://t.co/fyrvfchyNV',
#   'Tweets Ago': 7,
#   'User': 'CBSNews'},
#  {'Compound': -0.8957,
#   'Date': 'Wed Mar 07 06:54:05 +0000 2018',
#   'Negative': 0.545,
#   'Neutral': 0.455,
#   'Positive': 0.0,
#   'Tweet Text': 'Cop shot dead, 2 others wounded, suspect found dead in home https://t.co/Z0leIVkkAD https://t.co/m7kvHErhMw',
#   'Tweets Ago': 8,
#   'User': 'CBSNews'},
#  {'Compound': -0.5994,
#   'Date': 'Wed Mar 07 06:48:03 +0000 2018',
#   'Negative': 0.218,
#   'Neutral': 0.782,
#   'Positive': 0.0,
#   'Tweet Text': 'Man makes son run to school for being kicked off bus for bullying https://t.co/vw0FKUPDfi https://t.co/kDo8yCUvcR',
#   'Tweets Ago': 9,
#   'User': 'CBSNews'},
#  {'Compound': -0.875,
#   'Date': 'Wed Mar 07 06:33:04 +0000 2018',
#   'Negative': 0.5,
#   'Neutral': 0.5,
#   'Positive': 0.0,
#   'Tweet Text': 'DNA evidence links 1994 Montana killing to convicted murderer https://t.co/womHAy2BSH https://t.co/rduGWiJjw6',
#   'Tweets Ago': 10,
#   'User': 'CBSNews'},
#  {'Compound': -0.9001,
#   'Date': 'Wed Mar 07 06:18:09 +0000 2018',
#   'Negative': 0.5,
#   'Neutral': 0.5,
#   'Positive': 0.0,
#   'Tweet Text': "Pregnant mom charged in Maine girl's beating death is being abused in jail: attorney https://t.co/K52TFxLin9 https://t.co/tn5LO50k7I",
#   'Tweets Ago': 11,
#   'User': 'CBSNews'},
#  {'Compound': -0.6808,
#   'Date': 'Wed Mar 07 06:03:43 +0000 2018',
#   'Negative': 0.365,
#   'Neutral': 0.635,
#   'Positive': 0.0,
#   'Tweet Text': 'Police: Man raped daughter, fathered her 2 children https://t.co/dFGNTL5SsI https://t.co/74LkB4HrsR',
#   'Tweets Ago': 12,
#   'User': 'CBSNews'},
#  {'Compound': -0.4215,
#   'Date': 'Wed Mar 07 05:48:03 +0000 2018',
#   'Negative': 0.189,
#   'Neutral': 0.811,
#   'Positive': 0.0,
#   'Tweet Text': 'Oprah Winfrey explores revolutionary approach to childhood trauma for "60 Minutes" https://t.co/BjOOJfFbHW https://t.co/xPFmarJsCm',
#   'Tweets Ago': 13,
#   'User': 'CBSNews'},
#  {'Compound': -0.25,
#   'Date': 'Wed Mar 07 05:33:09 +0000 2018',
#   'Negative': 0.337,
#   'Neutral': 0.435,
#   'Positive': 0.228,
#   'Tweet Text': 'Basketball star Kevin Love opens up about panic attacks https://t.co/2QQtLDwfsP https://t.co/Eve7FYxoTF',
#   'Tweets Ago': 14,
#   'User': 'CBSNews'},
#  {'Compound': 0.4404,
#   'Date': 'Wed Mar 07 05:18:08 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.791,
#   'Positive': 0.209,
#   'Tweet Text': 'Japanese volcano spews ash, lava in strongest eruption in years https://t.co/BitRkvBvuq https://t.co/6JvZ8Fhx7l',
#   'Tweets Ago': 15,
#   'User': 'CBSNews'},
#  {'Compound': 0.6705,
#   'Date': 'Wed Mar 07 05:07:56 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.776,
#   'Positive': 0.224,
#   'Tweet Text': "Sen. Ted Cruz and Rep. Beto O'Rourke took the nomination for their respective parties in the primaries. Both will f… https://t.co/YRKeBDsJLG",
#   'Tweets Ago': 16,
#   'User': 'CBSNews'},
#  {'Compound': 0.0,
#   'Date': 'Wed Mar 07 05:00:11 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'Jared Kushner to visit Mexico, meet with Mexican president https://t.co/N27bWoM11j https://t.co/3IK7SLp23y',
#   'Tweets Ago': 17,
#   'User': 'CBSNews'},
#  {'Compound': 0.3182,
#   'Date': 'Wed Mar 07 04:50:01 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.892,
#   'Positive': 0.108,
#   'Tweet Text': "McDonald's is serving Quarter Pounders with fresh beef rather than frozen patties at about a quarter of its U.S. re… https://t.co/DbO5egblQq",
#   'Tweets Ago': 18,
#   'User': 'CBSNews'},
#  {'Compound': 0.0,
#   'Date': 'Wed Mar 07 04:43:32 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': "Texas' Republican Gov. Greg Abbott, who helped lead the state through Hurricane Harvey last fall, is all-but-certai… https://t.co/qkvoNCGXLt",
#   'Tweets Ago': 19,
#   'User': 'CBSNews'},
#  {'Compound': -0.6597,
#   'Date': 'Wed Mar 07 04:32:01 +0000 2018',
#   'Negative': 0.27,
#   'Neutral': 0.635,
#   'Positive': 0.095,
#   'Tweet Text': 'The State Department announced it has determined North Korea used chemical weapons last year in the assassination o… https://t.co/W8rLcp6kOt',
#   'Tweets Ago': 20,
#   'User': 'CBSNews'},
#  {'Compound': 0.4215,
#   'Date': 'Wed Mar 07 04:25:03 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.887,
#   'Positive': 0.113,
#   'Tweet Text': 'The Northeast is bracing for its second powerful storm in four days –– even as cities along the East Coast have yet… https://t.co/KttH6kVXBZ',
#   'Tweets Ago': 21,
#   'User': 'CBSNews'},
#  {'Compound': -0.5574,
#   'Date': 'Wed Mar 07 03:56:01 +0000 2018',
#   'Negative': 0.153,
#   'Neutral': 0.847,
#   'Positive': 0.0,
#   'Tweet Text': "Spurred by last year's mass shooting in Las Vegas, Washington became the latest in a handful of states to ban trigg… https://t.co/OJLuNZZ23c",
#   'Tweets Ago': 22,
#   'User': 'CBSNews'},
#  {'Compound': 0.0,
#   'Date': 'Wed Mar 07 03:35:01 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'A CBS News investigation of child labor in cobalt mines in the Democratic Republic of Congo has revealed that tens… https://t.co/GHBwAfZIOp',
#   'Tweets Ago': 23,
#   'User': 'CBSNews'},
#  {'Compound': 0.0,
#   'Date': 'Wed Mar 07 03:35:01 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'The former CEO of a payday lending company that had been under investigation by the Consumer Financial Protection B… https://t.co/1hOp28Hhc0',
#   'Tweets Ago': 24,
#   'User': 'CBSNews'},
#  {'Compound': -0.8834,
#   'Date': 'Wed Mar 07 03:15:03 +0000 2018',
#   'Negative': 0.407,
#   'Neutral': 0.593,
#   'Positive': 0.0,
#   'Tweet Text': "Indiana prosecutor files murder charges against a man in the fatal shooting of a sheriff's deputy during a foot cha… https://t.co/1wkUE3J6BQ",
#   'Tweets Ago': 25,
#   'User': 'CBSNews'},
#  {'Compound': 0.0,
#   'Date': 'Wed Mar 07 03:03:30 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': "RT @CBSEveningNews: NOW: @CBSEveningNews with @JeffGlor airs in its entirety on CBSN, @CBSNews' 24/7 streaming news service https://t.co/Me…",
#   'Tweets Ago': 26,
#   'User': 'CBSNews'},
#  {'Compound': 0.2878,
#   'Date': 'Wed Mar 07 02:49:01 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.898,
#   'Positive': 0.102,
#   'Tweet Text': "CBS News analyzed more than a decade's worth of House voting patterns, looking at trends in every district's past v… https://t.co/3jntx3cicy",
#   'Tweets Ago': 27,
#   'User': 'CBSNews'},
#  {'Compound': 0.0,
#   'Date': 'Wed Mar 07 02:40:55 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': '@CBSNews Michael Avenatti, the attorney representing Stormy Daniels, will be on @CBSThisMorning, Wednesday, March 7… https://t.co/xyvdH2eFJK',
#   'Tweets Ago': 28,
#   'User': 'CBSNews'},
#  {'Compound': 0.6369,
#   'Date': 'Wed Mar 07 02:30:01 +0000 2018',
#   'Negative': 0.07,
#   'Neutral': 0.65,
#   'Positive': 0.28,
#   'Tweet Text': "In Oval Office, President Trump expresses cautious optimism about North Korea's apparent willingness to negotiate… https://t.co/j6OjbJS1tZ",
#   'Tweets Ago': 29,
#   'User': 'CBSNews'},
#  {'Compound': 0.2732,
#   'Date': 'Wed Mar 07 02:28:00 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.896,
#   'Positive': 0.104,
#   'Tweet Text': "@CBSNews In October 2016, she accepted $130,000 from Mr. Trump's longtime attorney Michael Cohen in exchange for he… https://t.co/kgoAXWzAM5",
#   'Tweets Ago': 30,
#   'User': 'CBSNews'},
#  {'Compound': 0.3182,
#   'Date': 'Wed Mar 07 02:14:02 +0000 2018',
#   'Negative': 0.095,
#   'Neutral': 0.746,
#   'Positive': 0.159,
#   'Tweet Text': 'Adult film performer Stormy Daniels files lawsuit to void non-disclosure agreement with President Trump, claiming h… https://t.co/JBv9CGngko',
#   'Tweets Ago': 31,
#   'User': 'CBSNews'},
#  {'Compound': 0.8271,
#   'Date': 'Wed Mar 07 02:11:01 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.617,
#   'Positive': 0.383,
#   'Tweet Text': 'JUST IN: Justice Department plans to sue California over "sanctuary" laws that help protect undocumented immigrants… https://t.co/o5q38eZlUV',
#   'Tweets Ago': 32,
#   'User': 'CBSNews'},
#  {'Compound': 0.4215,
#   'Date': 'Wed Mar 07 01:35:49 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.872,
#   'Positive': 0.128,
#   'Tweet Text': "President John Tyler, who served from 1841 to 1845, was the United States' tenth commander-in-chief; two of his gra… https://t.co/rqsghbEPfY",
#   'Tweets Ago': 33,
#   'User': 'CBSNews'},
#  {'Compound': 0.0,
#   'Date': 'Wed Mar 07 01:20:01 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'Texas is holding the first primary of the 2018 midterm election season. Track updates here: https://t.co/TkuvTA3480 https://t.co/LMAiVcI0Kb',
#   'Tweets Ago': 34,
#   'User': 'CBSNews'},
#  {'Compound': 0.0,
#   'Date': 'Wed Mar 07 01:10:01 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'In 45 states, opioid overdoses rose 30 percent in a year, according to new data from the CDC, indicating that the U… https://t.co/6iKGF11Pnq',
#   'Tweets Ago': 35,
#   'User': 'CBSNews'},
#  {'Compound': 0.0,
#   'Date': 'Wed Mar 07 00:50:01 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': "Speculation over Gary Cohn's tenure in the White House ramped up last week after Pres. Trump announced the 25 perce… https://t.co/NcqqKRg1md",
#   'Tweets Ago': 36,
#   'User': 'CBSNews'},
#  {'Compound': 0.0,
#   'Date': 'Wed Mar 07 00:30:02 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'The northeast is bracing for round two -- a second major storm in four days; heavy snow, rain and high winds will m… https://t.co/3x1ofE4hZ3',
#   'Tweets Ago': 37,
#   'User': 'CBSNews'},
#  {'Compound': -0.1779,
#   'Date': 'Wed Mar 07 00:10:43 +0000 2018',
#   'Negative': 0.141,
#   'Neutral': 0.747,
#   'Positive': 0.112,
#   'Tweet Text': 'White House aide Kellyanne Conway violated the Hatch Act on two separate occasions, the Office of Special Counsel c… https://t.co/uweIuFHChL',
#   'Tweets Ago': 38,
#   'User': 'CBSNews'},
#  {'Compound': -0.1027,
#   'Date': 'Wed Mar 07 00:07:41 +0000 2018',
#   'Negative': 0.062,
#   'Neutral': 0.938,
#   'Positive': 0.0,
#   'Tweet Text': '"I find it hard to believe." Two grandsons of former U.S. president John Tyler are still around nearly 175 after Ty… https://t.co/qpMpX1xgNk',
#   'Tweets Ago': 39,
#   'User': 'CBSNews'},
#  {'Compound': -0.128,
#   'Date': 'Tue Mar 06 23:58:03 +0000 2018',
#   'Negative': 0.077,
#   'Neutral': 0.923,
#   'Positive': 0.0,
#   'Tweet Text': 'Most public schools will be open in West Virginia tomorrow. Teachers are ending their strike and getting a raise.… https://t.co/nJ8oi1HnZ5',
#   'Tweets Ago': 40,
#   'User': 'CBSNews'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 23:56:29 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': "CBS News investigates the mining of cobalt used in many lithium ion batteries. More than half the world's cobalt co… https://t.co/7Pebz7gCCA",
#   'Tweets Ago': 41,
#   'User': 'CBSNews'},
#  {'Compound': -0.8689,
#   'Date': 'Tue Mar 06 23:52:10 +0000 2018',
#   'Negative': 0.366,
#   'Neutral': 0.634,
#   'Positive': 0.0,
#   'Tweet Text': "New numbers out today show America's opioid crisis is getting worse. In 45 states, emergency room visits for opioid… https://t.co/tq1WQvxDur",
#   'Tweets Ago': 42,
#   'User': 'CBSNews'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 23:49:53 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': ".@WBZ's @ericfisher breaks down the projected snowfall along the East Coast as another major nor'easter approaches. https://t.co/GfVvrt4T1v",
#   'Tweets Ago': 43,
#   'User': 'CBSNews'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 23:44:20 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'The Northeast is bracing for round two tonight, a second major storm in four days. Heavy snow, rain, and wind will… https://t.co/4NxfFSrvZ8',
#   'Tweets Ago': 44,
#   'User': 'CBSNews'},
#  {'Compound': 0.3612,
#   'Date': 'Tue Mar 06 23:41:25 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.889,
#   'Positive': 0.111,
#   'Tweet Text': 'North Korean leader Kim Jong Un is reportedly ready to open talks with the U.S. about scrapping his nuclear arsenal… https://t.co/5W6IrIqySe',
#   'Tweets Ago': 45,
#   'User': 'CBSNews'},
#  {'Compound': -0.25,
#   'Date': 'Tue Mar 06 23:37:40 +0000 2018',
#   'Negative': 0.125,
#   'Neutral': 0.875,
#   'Positive': 0.0,
#   'Tweet Text': "The president's chief economic adviser, Gary Cohn, resigned. @nancycordes has more on the @CBSEveningNews.… https://t.co/CtnznV4iy0",
#   'Tweets Ago': 46,
#   'User': 'CBSNews'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 23:14:01 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': "Hard-hit New England prepares for another massive winter storm after last week's deadly nor'easter.… https://t.co/181VINSUT9",
#   'Tweets Ago': 47,
#   'User': 'CBSNews'},
#  {'Compound': -0.1531,
#   'Date': 'Tue Mar 06 22:48:59 +0000 2018',
#   'Negative': 0.099,
#   'Neutral': 0.826,
#   'Positive': 0.074,
#   'Tweet Text': "JUST IN: Gary Cohn, Pres. Trump's top economic adviser, to resign; the exit of the Goldman Sachs alum, who has serv… https://t.co/QHxCwNP0kU",
#   'Tweets Ago': 48,
#   'User': 'CBSNews'},
#  {'Compound': 0.4939,
#   'Date': 'Tue Mar 06 22:30:01 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.856,
#   'Positive': 0.144,
#   'Tweet Text': 'President Trump praised Sweden as one of the largest investors in the U.S., specifically, the eighth largest. CBS N… https://t.co/OZDkXJ418u',
#   'Tweets Ago': 49,
#   'User': 'CBSNews'},
#  {'Compound': -0.3818,
#   'Date': 'Tue Mar 06 22:04:18 +0000 2018',
#   'Negative': 0.11,
#   'Neutral': 0.89,
#   'Positive': 0.0,
#   'Tweet Text': 'The USS Lexington, nicknamed "Lady Lex," was crippled during a battle in 1942 and was just found off the coast of A… https://t.co/8fW81xsdgh',
#   'Tweets Ago': 50,
#   'User': 'CBSNews'},
#  {'Compound': -0.7096,
#   'Date': 'Tue Mar 06 21:45:01 +0000 2018',
#   'Negative': 0.318,
#   'Neutral': 0.578,
#   'Positive': 0.105,
#   'Tweet Text': 'In patients with chronic back pain or hip or knee arthritis, opioids worked no better than over-the-counter pain re… https://t.co/2CV29FNUAS',
#   'Tweets Ago': 51,
#   'User': 'CBSNews'},
#  {'Compound': 0.3818,
#   'Date': 'Tue Mar 06 21:30:45 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.88,
#   'Positive': 0.12,
#   'Tweet Text': '"Flippy," a machine that costs $60,000 to $100,000, depending on its features, and is said to be capable of flippin… https://t.co/ey7boauh7k',
#   'Tweets Ago': 52,
#   'User': 'CBSNews'},
#  {'Compound': -0.1531,
#   'Date': 'Tue Mar 06 21:11:21 +0000 2018',
#   'Negative': 0.082,
#   'Neutral': 0.918,
#   'Positive': 0.0,
#   'Tweet Text': 'Q: What do you think Sweden should learn from how the Russian influence campaign affected the presidential election… https://t.co/O9dNeXyNfc',
#   'Tweets Ago': 53,
#   'User': 'CBSNews'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 21:07:03 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'When asked about seeing change in his White House cabinet or with Attorney General Jeff Sessions, Trump said, "Ther… https://t.co/QRQ1gl1Qa0',
#   'Tweets Ago': 54,
#   'User': 'CBSNews'},
#  {'Compound': -0.228,
#   'Date': 'Tue Mar 06 20:57:12 +0000 2018',
#   'Negative': 0.201,
#   'Neutral': 0.66,
#   'Positive': 0.138,
#   'Tweet Text': "Q: How do you avoid this escalating trade war?\nTrump: We will straighten it out. We'll do it in a very loving way.… https://t.co/taoCllWlxL",
#   'Tweets Ago': 55,
#   'User': 'CBSNews'},
#  {'Compound': 0.1027,
#   'Date': 'Tue Mar 06 20:53:53 +0000 2018',
#   'Negative': 0.106,
#   'Neutral': 0.769,
#   'Positive': 0.125,
#   'Tweet Text': '.@POTUS reaffirms commitment to impose tariffs despite objections from GOP leaders, saying we cannot "lose" steel a… https://t.co/FwDFlJZlkS',
#   'Tweets Ago': 56,
#   'User': 'CBSNews'},
#  {'Compound': 0.4939,
#   'Date': 'Tue Mar 06 20:50:04 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.802,
#   'Positive': 0.198,
#   'Tweet Text': '.@POTUS announces Sweden plans to procure military deal worth $3 billion with U.S. that "will increase stability an… https://t.co/DzZoJh1a8J',
#   'Tweets Ago': 57,
#   'User': 'CBSNews'},
#  {'Compound': 0.296,
#   'Date': 'Tue Mar 06 20:41:31 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.901,
#   'Positive': 0.099,
#   'Tweet Text': 'WATCH LIVE: Pres. Trump, Swedish PM hold joint news conference at White House after Trump comments on prospect of t… https://t.co/PVEm20sVTC',
#   'Tweets Ago': 58,
#   'User': 'CBSNews'},
#  {'Compound': -0.296,
#   'Date': 'Tue Mar 06 20:30:02 +0000 2018',
#   'Negative': 0.115,
#   'Neutral': 0.885,
#   'Positive': 0.0,
#   'Tweet Text': 'SOON: President Trump holds joint news conference with Swedish prime minister after announcing plan to impose tarif… https://t.co/Qmfl9lodeH',
#   'Tweets Ago': 59,
#   'User': 'CBSNews'},
#  {'Compound': -0.0772,
#   'Date': 'Tue Mar 06 20:15:53 +0000 2018',
#   'Negative': 0.071,
#   'Neutral': 0.929,
#   'Positive': 0.0,
#   'Tweet Text': 'President Trump says there\'s a "serious effort" underway with the North and South Koreans following news that North… https://t.co/T9PcFi9KPP',
#   'Tweets Ago': 60,
#   'User': 'CBSNews'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 20:00:31 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': "The little girl who was photographed looking awestruck at Michelle Obama's portrait got to meet -- and dance -- wit… https://t.co/aPxki5zzVt",
#   'Tweets Ago': 61,
#   'User': 'CBSNews'},
#  {'Compound': -0.5267,
#   'Date': 'Tue Mar 06 19:45:01 +0000 2018',
#   'Negative': 0.159,
#   'Neutral': 0.841,
#   'Positive': 0.0,
#   'Tweet Text': 'White House aide and spokesperson Kellyanne Conway violated the Hatch Act on two separate occasions, Office of Spec… https://t.co/0qQ6G0Jvia',
#   'Tweets Ago': 62,
#   'User': 'CBSNews'},
#  {'Compound': -0.2732,
#   'Date': 'Tue Mar 06 19:31:54 +0000 2018',
#   'Negative': 0.116,
#   'Neutral': 0.884,
#   'Positive': 0.0,
#   'Tweet Text': 'U.S. embassy workers have been warned after an apparent explosive device was found on a Mexican ferry:… https://t.co/dYEeaSMyLW',
#   'Tweets Ago': 63,
#   'User': 'CBSNews'},
#  {'Compound': 0.4588,
#   'Date': 'Tue Mar 06 19:30:03 +0000 2018',
#   'Negative': 0.083,
#   'Neutral': 0.72,
#   'Positive': 0.197,
# ...
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'RT @NYTObits: Alan Gershwin, a man who insisted for 70 years or so that he was the illegitimate son of George Gershwin, and who made a virt…',
#   'Tweets Ago': 51,
#   'User': 'nytimes'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 21:42:03 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'An employee at OpenTable booked hundreds of tables at Chicago restaurants, using a rival service, with the intent o… https://t.co/H2kPuXg4RY',
#   'Tweets Ago': 52,
#   'User': 'nytimes'},
#  {'Compound': -0.296,
#   'Date': 'Tue Mar 06 21:28:06 +0000 2018',
#   'Negative': 0.104,
#   'Neutral': 0.896,
#   'Positive': 0.0,
#   'Tweet Text': 'China was mentioned only in broad terms when Trump announced plans to impose tariffs on steel and aluminum imports.… https://t.co/hyIKpH14Yu',
#   'Tweets Ago': 53,
#   'User': 'nytimes'},
#  {'Compound': 0.6344,
#   'Date': 'Tue Mar 06 21:18:08 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.812,
#   'Positive': 0.188,
#   'Tweet Text': 'RT @BasseyE: There are few things more essentially joyful than an NYT comments section about Mr. Rodgers. \n\nhttps://t.co/cCFv57KRjF https:/…',
#   'Tweets Ago': 54,
#   'User': 'nytimes'},
#  {'Compound': -0.3612,
#   'Date': 'Tue Mar 06 21:08:04 +0000 2018',
#   'Negative': 0.2,
#   'Neutral': 0.8,
#   'Positive': 0.0,
#   'Tweet Text': "Low-effort, high-reward cooking for when you're hungry and exhausted https://t.co/bZIEYqKJqs https://t.co/GW2KJO3SFJ",
#   'Tweets Ago': 55,
#   'User': 'nytimes'},
#  {'Compound': -0.1027,
#   'Date': 'Tue Mar 06 20:53:06 +0000 2018',
#   'Negative': 0.142,
#   'Neutral': 0.733,
#   'Positive': 0.125,
#   'Tweet Text': 'Bill Clinton, George Bush and Barack Obama have all experienced bursts of hope and then inevitable disappointment i… https://t.co/yJylpWJvhe',
#   'Tweets Ago': 56,
#   'User': 'nytimes'},
#  {'Compound': -0.7906,
#   'Date': 'Tue Mar 06 20:38:04 +0000 2018',
#   'Negative': 0.292,
#   'Neutral': 0.708,
#   'Positive': 0.0,
#   'Tweet Text': 'An Indian-born engineer was fatally shot last year after a Kansas man angrily asked him about his immigration statu… https://t.co/WvKSe2gdlk',
#   'Tweets Ago': 57,
#   'User': 'nytimes'},
#  {'Compound': 0.4939,
#   'Date': 'Tue Mar 06 20:23:06 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.811,
#   'Positive': 0.189,
#   'Tweet Text': 'While hosting Benjamin Netanyahu, Trump said he still had “a good chance” of forging peace, but a deal seems furthe… https://t.co/HfdLV6W7fS',
#   'Tweets Ago': 58,
#   'User': 'nytimes'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 20:08:05 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': "They've never run a restaurant before. But they're bringing Sanjeev Kapoor's cooking to America. https://t.co/kwL0W6LKng",
#   'Tweets Ago': 59,
#   'User': 'nytimes'},
#  {'Compound': -0.5267,
#   'Date': 'Tue Mar 06 19:53:03 +0000 2018',
#   'Negative': 0.152,
#   'Neutral': 0.848,
#   'Positive': 0.0,
#   'Tweet Text': 'For the first time, a Belgian criminal court has convicted a man of “sexism in the public space” for verbally abusi… https://t.co/EFst3EANcJ',
#   'Tweets Ago': 60,
#   'User': 'nytimes'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 19:38:05 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': "An NYT reader's reaction to Kim Jong-un reportedly telling South Korea he is willing to negotiate with the U.S. on… https://t.co/lc7e7x6odK",
#   'Tweets Ago': 61,
#   'User': 'nytimes'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 19:23:03 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': "On the 20th Anniversary of “The Big Lebowski,” here's a list of streamable movies that follow in the footsteps of e… https://t.co/oLwo4JfXS5",
#   'Tweets Ago': 62,
#   'User': 'nytimes'},
#  {'Compound': -0.5574,
#   'Date': 'Tue Mar 06 19:13:05 +0000 2018',
#   'Negative': 0.126,
#   'Neutral': 0.874,
#   'Positive': 0.0,
#   'Tweet Text': 'RT @NYTArchives: The artist Georgia O\'Keeffe died at age 98 on this day in 1986. In her obituary, The Times said that "she raised the aware…',
#   'Tweets Ago': 63,
#   'User': 'nytimes'},
#  {'Compound': -0.2263,
#   'Date': 'Tue Mar 06 19:03:05 +0000 2018',
#   'Negative': 0.139,
#   'Neutral': 0.861,
#   'Positive': 0.0,
#   'Tweet Text': "West Virginia lawmakers passed a 5% pay raise in a deal to end a teachers' strike that has shuttered schools for ne… https://t.co/Uw3ySmhWeU",
#   'Tweets Ago': 64,
#   'User': 'nytimes'},
#  {'Compound': 0.2023,
#   'Date': 'Tue Mar 06 18:48:32 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.913,
#   'Positive': 0.087,
#   'Tweet Text': 'The corruption trial of a former top aide to Governor Andrew Cuomo could be headed to a mistrial after jurors said… https://t.co/PNcdu5Uzse',
#   'Tweets Ago': 65,
#   'User': 'nytimes'},
#  {'Compound': -0.1027,
#   'Date': 'Tue Mar 06 18:20:12 +0000 2018',
#   'Negative': 0.085,
#   'Neutral': 0.915,
#   'Positive': 0.0,
#   'Tweet Text': 'RT @NYTNational: ⚡️ “West Virginia leaders say a deal to raise teachers’ pay may end strike”\n\nhttps://t.co/NSjb9xC5Ym',
#   'Tweets Ago': 66,
#   'User': 'nytimes'},
#  {'Compound': -0.4215,
#   'Date': 'Tue Mar 06 18:10:09 +0000 2018',
#   'Negative': 0.256,
#   'Neutral': 0.56,
#   'Positive': 0.184,
#   'Tweet Text': 'If the mainstream media is a perennial enemy of the right, Big Tech is a fresh and novel foe https://t.co/LmKL26lpDo',
#   'Tweets Ago': 67,
#   'User': 'nytimes'},
#  {'Compound': 0.2411,
#   'Date': 'Tue Mar 06 17:55:27 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.897,
#   'Positive': 0.103,
#   'Tweet Text': "The destinies of Alexander Litvinenko and Sergei Skripal carry similarities that can't be ignored, offering proof t… https://t.co/JvUPrzEFVx",
#   'Tweets Ago': 68,
#   'User': 'nytimes'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 17:40:06 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'RT @cliffordlevy: .@nytimes put out a call for contributors because we wanted to elevate the voices of college students and recent graduate…',
#   'Tweets Ago': 69,
#   'User': 'nytimes'},
#  {'Compound': -0.2732,
#   'Date': 'Tue Mar 06 17:30:21 +0000 2018',
#   'Negative': 0.1,
#   'Neutral': 0.9,
#   'Positive': 0.0,
#   'Tweet Text': 'Forecasters warned up to a foot of snow could fall in parts of New York, New Jersey, Connecticut and Massachusetts https://t.co/AYbdk58zDE',
#   'Tweets Ago': 70,
#   'User': 'nytimes'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 17:20:11 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'RT @NYTArchives: A look back at our film review of "The Big Lebowski" which published on this day 20 years ago. https://t.co/wy3gpv6ACJ htt…',
#   'Tweets Ago': 71,
#   'User': 'nytimes'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 17:07:48 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': '“Bringing all of these women together, meeting and seeing each other for who we are ... that’s healing”… https://t.co/4VCkhHpcpZ',
#   'Tweets Ago': 72,
#   'User': 'nytimes'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 17:06:47 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'For some players, the team is the first step in learning about their families. Christine Phillips-Ryburn, a.k.a. “W… https://t.co/hsvLm3LXGj',
#   'Tweets Ago': 73,
#   'User': 'nytimes'},
#  {'Compound': -0.4168,
#   'Date': 'Tue Mar 06 17:04:42 +0000 2018',
#   'Negative': 0.127,
#   'Neutral': 0.873,
#   'Positive': 0.0,
#   'Tweet Text': 'For these women, representing Team Indigenous at the Roller Derby World Cup is not just about winning.\xa0Sasheen Wesl… https://t.co/c4yM3oo62D',
#   'Tweets Ago': 74,
#   'User': 'nytimes'},
#  {'Compound': 0.4118,
#   'Date': 'Tue Mar 06 17:01:43 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.867,
#   'Positive': 0.133,
#   'Tweet Text': '“Even though we’re all from different nations, we all have this shared history of being indigenous people.” — Laura… https://t.co/q01ub072pU',
#   'Tweets Ago': 75,
#   'User': 'nytimes'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 17:00:08 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': '“Strong! Resilient! Indigenous!” chants Victoria Lynn Major, a.k.a. “Rage,” with the team before a game… https://t.co/w00MmueVHj',
#   'Tweets Ago': 76,
#   'User': 'nytimes'},
#  {'Compound': 0.4215,
#   'Date': 'Tue Mar 06 16:58:10 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.851,
#   'Positive': 0.149,
#   'Tweet Text': '“When I talk about decolonizing roller derby, I talk about recognizing that opportunity and access exist in roller… https://t.co/IeXaYhZ1k0',
#   'Tweets Ago': 77,
#   'User': 'nytimes'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 16:55:50 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'They are astronomers, lawyers, postal workers, heavy machine operators and grandmothers. Meet the roller derby athl… https://t.co/DP6F6IOiW1',
#   'Tweets Ago': 78,
#   'User': 'nytimes'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 16:53:20 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'Team Indigenous, which includes 20 athletes from indigenous communities in Canada, the U.S., South America, New Zea… https://t.co/PBUpIt2IYn',
#   'Tweets Ago': 79,
#   'User': 'nytimes'},
#  {'Compound': -0.8519,
#   'Date': 'Tue Mar 06 16:45:04 +0000 2018',
#   'Negative': 0.329,
#   'Neutral': 0.671,
#   'Positive': 0.0,
#   'Tweet Text': 'RT @abscribe: Last summer, I profiled Sunayana Dumala, the widow of a hate crime victim in Kansas. Months later, I went back for a public f…',
#   'Tweets Ago': 80,
#   'User': 'nytimes'},
#  {'Compound': -0.3182,
#   'Date': 'Tue Mar 06 16:35:05 +0000 2018',
#   'Negative': 0.103,
#   'Neutral': 0.897,
#   'Positive': 0.0,
#   'Tweet Text': 'He spoke of a subpoena, then gave odd TV interviews. But will Sam Nunberg, an ex-Trump aide, testify in the Russia… https://t.co/bUDmh3ieBR',
#   'Tweets Ago': 81,
#   'User': 'nytimes'},
#  {'Compound': -0.4767,
#   'Date': 'Tue Mar 06 16:25:06 +0000 2018',
#   'Negative': 0.19,
#   'Neutral': 0.733,
#   'Positive': 0.077,
#   'Tweet Text': 'RT @NYTNational: Mayor Megan Barry of Nashville pleaded guilty to theft of property and agreed to resign on Tuesday. She had faced question…',
#   'Tweets Ago': 82,
#   'User': 'nytimes'},
#  {'Compound': -0.34,
#   'Date': 'Tue Mar 06 16:10:04 +0000 2018',
#   'Negative': 0.118,
#   'Neutral': 0.882,
#   'Positive': 0.0,
#   'Tweet Text': 'Following a string of mass shootings and nationwide calls for gun control in recent weeks, Bumble is banning images… https://t.co/PTyjUPQ87v',
#   'Tweets Ago': 83,
#   'User': 'nytimes'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 16:05:36 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': "Late-Night Roundup: Stephen Colbert went to town on Sam Nunberg's numerous interviews on whether he would comply wi… https://t.co/eX8T6RKGFa",
#   'Tweets Ago': 84,
#   'User': 'nytimes'},
#  {'Compound': 0.3291,
#   'Date': 'Tue Mar 06 15:55:03 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.879,
#   'Positive': 0.121,
#   'Tweet Text': "Happy Birthday, Gabriel García Márquez.\n\nFrom December: Márquez's literary remains may be in Texas, but a new digit… https://t.co/Py3fIZ0p2J",
#   'Tweets Ago': 85,
#   'User': 'nytimes'},
#  {'Compound': 0.1779,
#   'Date': 'Tue Mar 06 15:40:15 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.918,
#   'Positive': 0.082,
#   'Tweet Text': "If Martin Shkreli can't come up with the $7 million he owes the government, his assets —including a one-of-a-kind W… https://t.co/vGvd4PJyxU",
#   'Tweets Ago': 86,
#   'User': 'nytimes'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 15:25:04 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'Broadcom’s efforts to buy Qualcomm may have been stymied, as U.S. officials said the Singapore firm’s bid could pos… https://t.co/05lDqXfT6C',
#   'Tweets Ago': 87,
#   'User': 'nytimes'},
#  {'Compound': -0.4215,
#   'Date': 'Tue Mar 06 15:10:06 +0000 2018',
#   'Negative': 0.118,
#   'Neutral': 0.882,
#   'Positive': 0.0,
#   'Tweet Text': 'Paul Ryan has modeled himself as the face of a new brand of conservatism, but critics say he is too deferential to… https://t.co/NPP4A43yO1',
#   'Tweets Ago': 88,
#   'User': 'nytimes'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 14:55:00 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'New York Times reporter @DanBilefsky recently returned to his hometown, Montreal, to write about Canada. Next week,… https://t.co/NSab3Vrzs5',
#   'Tweets Ago': 89,
#   'User': 'nytimes'},
#  {'Compound': 0.4767,
#   'Date': 'Tue Mar 06 14:45:07 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.838,
#   'Positive': 0.162,
#   'Tweet Text': '“Everyone in Montreal is proud of Leonard Cohen — the French, the English; he is sacred here" https://t.co/mzw4EUVbxr',
#   'Tweets Ago': 90,
#   'User': 'nytimes'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 14:30:08 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': 'Over 5 months after Hurricane Maria plowed through Puerto Rico, some parts of the island are still in the dark. It… https://t.co/0VmYng0hCf',
#   'Tweets Ago': 91,
#   'User': 'nytimes'},
#  {'Compound': -0.5719,
#   'Date': 'Tue Mar 06 14:15:03 +0000 2018',
#   'Negative': 0.222,
#   'Neutral': 0.778,
#   'Positive': 0.0,
#   'Tweet Text': 'President Trump pushed back against reports that his White House is in chaos https://t.co/Y9riFXzyfC',
#   'Tweets Ago': 92,
#   'User': 'nytimes'},
#  {'Compound': 0.5574,
#   'Date': 'Tue Mar 06 13:45:11 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.841,
#   'Positive': 0.159,
#   'Tweet Text': '15 remarkable books by women that are shaping the way we read and write fiction in the 21st century https://t.co/hJ2bfFj0GU',
#   'Tweets Ago': 93,
#   'User': 'nytimes'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 13:30:20 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': "Morning Briefing: Here's what you need to know to start your day https://t.co/b1jtS4G59o",
#   'Tweets Ago': 94,
#   'User': 'nytimes'},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 13:16:03 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Tweet Text': "RT @NYTNational: Should Florida's teachers be armed? Lawmakers seem against the idea, but they will consider allowing librarians, counselor…",
#   'Tweets Ago': 95,
#   'User': 'nytimes'},
#  {'Compound': -0.5423,
#   'Date': 'Tue Mar 06 13:02:07 +0000 2018',
#   'Negative': 0.246,
#   'Neutral': 0.632,
#   'Positive': 0.123,
#   'Tweet Text': 'First Ray, then Patsy, now Joe. After a period of peace, another pizza war has broken out in New York City. https://t.co/rcKlbhE3c3',
#   'Tweets Ago': 96,
#   'User': 'nytimes'},
#  {'Compound': 0.3182,
#   'Date': 'Tue Mar 06 12:47:02 +0000 2018',
#   'Negative': 0.086,
#   'Neutral': 0.769,
#   'Positive': 0.145,
#   'Tweet Text': 'A cruise skeptic tries to enjoy 4 days on the high seas with his family, Mickey and a bunch of princesses https://t.co/IOhiRotXfS',
#   'Tweets Ago': 97,
#   'User': 'nytimes'},
#  {'Compound': 0.25,
#   'Date': 'Tue Mar 06 12:33:04 +0000 2018',
#   'Negative': 0.155,
#   'Neutral': 0.655,
#   'Positive': 0.19,
#   'Tweet Text': '"The greatest challenge to lasting weight loss is the fact that no one can give up eating. Rather, one has to learn… https://t.co/bPS4HEpCMw',
#   'Tweets Ago': 98,
#   'User': 'nytimes'},
#  {'Compound': -0.0679,
#   'Date': 'Tue Mar 06 12:17:01 +0000 2018',
#   'Negative': 0.146,
#   'Neutral': 0.754,
#   'Positive': 0.1,
#   'Tweet Text': 'RT @nytopinion: The teacher strike in West Virginia is a reminder of the period of more open class struggle in the United States, says @sar…',
#   'Tweets Ago': 99,
#   'User': 'nytimes'},
#  {'Compound': -0.7845,
#   'Date': 'Tue Mar 06 12:02:12 +0000 2018',
#   'Negative': 0.247,
#   'Neutral': 0.753,
#   'Positive': 0.0,
#   'Tweet Text': '10 years after a cancer diagnosis, one man is still tens of thousands of dollars in debt over the cost of a drug he… https://t.co/7zC6Fyh5ed',
#   'Tweets Ago': 100,
#   'User': 'nytimes'}]

# %%
# Convert sentiments to DataFrame
sentiments_df = pd.DataFrame.from_dict(sentiments)

sentiments_df.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0    0.0000  Wed Mar 07 08:26:06 +0000 2018     0.000    1.000      0.00
# 1   -0.4019  Wed Mar 07 08:17:45 +0000 2018     0.252    0.748      0.00
# 2   -0.3818  Wed Mar 07 08:17:43 +0000 2018     0.245    0.755      0.00
# 3    0.1531  Wed Mar 07 08:12:47 +0000 2018     0.268    0.352      0.38
# 4   -0.2263  Wed Mar 07 07:56:51 +0000 2018     0.087    0.913      0.00
#
#                                           Tweet Text  Tweets Ago      User
# 0  RT @SallyBundockBBC: #Mattel is marking #Inter...           1  BBCWorld
# 1  Terminal illness led to Australia's first same...           2  BBCWorld
# 2  Blackberry sues Facebook in fight over app pat...           3  BBCWorld
# 3  Fyre Festival co-founder Billy McFarland admit...           4  BBCWorld
# 4  RT @BBCSteveR: What are today's Russian papers...           5  BBCWorld

# %%
# Export dataframe to a csv
sentiments_df.to_csv("csv_data.csv")

# %%
date = time.strftime("%m/%d/%Y")

colors = ["lightblue", "green", "red", "blue", "orange"]

# counter
i = 0

# Loop through all target users and plot scatterplot
for user in target_users:
    new_df = sentiments_df.loc[sentiments_df["User"] == user]   
    plt.scatter(new_df["Tweets Ago"], new_df["Compound"], label = user, 
                s = 100, color = colors[i], edgecolors = "black", alpha = 0.8)
    i = i + 1

# x-limit, y-limit, Grid and Legends for scatterplot
plt.xlim(105, -5)
plt.ylim(-1.05, 1.05)
plt.grid()
plt.legend(bbox_to_anchor = (1,1), title = "Media Sources", edgecolor = "black")

# Chart Title, x-label and y-label
plt.title("Sentiment analysis of Media Tweets (%s)" % date)
plt.xlabel("Tweets Ago")
plt.ylabel("Tweet Polarity")

# Export and save Bar plot
plt.savefig("Scatterplot_SentimentAnalysis.png", bbox_inches = "tight")

# Print chart to the screen
plt.show()

# %%
ave_sentiment_by_source = sentiments_df.groupby("User")["Compound"].mean()
ave_sentiment_by_source
# Out:
# User
# BBCWorld   -0.103437
# CBSNews    -0.086055
# CNN        -0.029067
# FOXNews    -0.020007
# nytimes    -0.008218
# Name: Compound, dtype: float64

# %%
# Define x-axis and xlabels
x_axis = np.arange(len(ave_sentiment_by_source))
x_labels = ave_sentiment_by_source.index

# Plot bar graph and assign appropriate parameters
plt.bar(x_axis, ave_sentiment_by_source, width = 1, tick_label = x_labels,
        color = colors, alpha = 0.75, align = "edge", edgecolor = "black")
tick_locations = [i+0.5 for i in x_axis]
plt.xticks(tick_locations, ["BBC", "CBS", "CNN", "FOX", "NYT"])

# Chart Title, x-label and y-label
plt.title("Overall Media Sentiment based on Twitter (%s)" % date)
plt.xlabel("Media Sources")
plt.ylabel("Tweet Polarity")

# Export and save Bar plot
plt.savefig("Barplot_OverallSentiment.png")

# Print chart to the screen
plt.show()
